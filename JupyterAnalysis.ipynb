# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('weight-height.csv')

data
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %% [markdown]
# # **Population Statistics:**

# %%
population_height_mean = round(data['Height'].mean(),3)
population_height_std = round(data['Height'].std(ddof=0),3)

print(f'Population height mean: {population_height_mean}','\n\n'
      f'Population height standard deviation: {population_height_std}')
# Out:
# Population height mean: 66.368
#
# Population height standard deviation: 3.847

# %%
sns.histplot(data=data['Height'],bins=30,stat='density',color='beige')
sns.kdeplot(data=data['Height'],color='red')
plt.xlabel('Height')
plt.ylabel('Probability Density')
plt.title('Population Histogram of Height')
plt.axvline(population_height_mean,label='Population mean',linewidth=2)
plt.legend()
plt.show()

# %% [markdown]
# # **Sample Analysis For Mean:**

# %%
# 100 samples of size n = 5

random_500 = np.array(data['Height'][np.random.randint(0,10000,500)]).reshape(100,5)

individual_means_of_100_samples_of_5 = random_500.mean(axis=1)

# %%
mean_of_individual_means_of_5 = round(individual_means_of_100_samples_of_5.mean(),3)
std_of_individual_means_of_5 = round(individual_means_of_100_samples_of_5.std(ddof=1),3)
theo_std_5 = round(population_height_std/(5)**(1/2),3)

print(f'Sample height mean: {mean_of_individual_means_of_5}','\n\n'
      f'Sample height standard deviation: {std_of_individual_means_of_5}','\n\n'
      f'Theoritical Sample height standard deviation: {theo_std_5}')
# Out:
# Sample height mean: 66.175
#
# Sample height standard deviation: 1.731
#
# Theoritical Sample height standard deviation: 1.72

# %%
sns.histplot(data=individual_means_of_100_samples_of_5,bins=30,stat='density',color='beige')
sns.kdeplot(data=individual_means_of_100_samples_of_5,color='red')
plt.xlabel('Height')
plt.ylabel('Probability Density')
plt.title('Means of 100 Samples of size = 5 Histogram')
plt.axvline(population_height_mean,label='Population mean',linewidth=2)
plt.axvline(mean_of_individual_means_of_5,label='Sample mean',linewidth=2,color='green')
plt.legend()
plt.show()

# %%
# 100 samples of size n = 10

random_1000 = np.array(data['Height'][np.random.randint(0,10000,1000)]).reshape(100,10)

individual_means_of_100_samples_of_10 = random_1000.mean(axis=1)

# %%
mean_of_individual_means_of_10 = round(individual_means_of_100_samples_of_10.mean(),3)
std_of_individual_means_of_10 = round(individual_means_of_100_samples_of_10.std(ddof=1),3)
theo_std_10 = round(population_height_std/(10)**(1/2),3)

print(f'Sample height mean: {mean_of_individual_means_of_10}','\n\n'
      f'Sample height standard deviation: {std_of_individual_means_of_10}','\n\n'
      f'Theoritical Sample height standard deviation: {theo_std_10}')
# Out:
# Sample height mean: 66.236
#
# Sample height standard deviation: 1.391
#
# Theoritical Sample height standard deviation: 1.217

# %%
sns.histplot(data=individual_means_of_100_samples_of_10,bins=30,stat='density',color='beige')
sns.kdeplot(data=individual_means_of_100_samples_of_10,color='red')
plt.xlabel('Height')
plt.ylabel('Probability Density')
plt.title('Means of 100 Samples of size = 10 Histogram')
plt.axvline(population_height_mean,label='Population mean',linewidth=2)
plt.axvline(mean_of_individual_means_of_10,label='Sample mean',linewidth=2,color='green')
plt.legend()
plt.show()

# %%
# 100 samples of size n = 30

random_3000 = np.array(data['Height'][np.random.randint(0,10000,3000)]).reshape(100,30)

individual_means_of_100_samples_of_30 = random_3000.mean(axis=1)

# %%
mean_of_individual_means_of_30 = round(individual_means_of_100_samples_of_30.mean(),3)
std_of_individual_means_of_30 = round(individual_means_of_100_samples_of_30.std(ddof=1),3)
theo_std_30 = round(population_height_std/(30)**(1/2),3)

print(f'Sample height mean: {mean_of_individual_means_of_30}','\n\n'
      f'Sample height standard deviation: {std_of_individual_means_of_30}','\n\n'
      f'Theoritical Sample height standard deviation: {theo_std_30}')
# Out:
# Sample height mean: 66.328
#
# Sample height standard deviation: 0.632
#
# Theoritical Sample height standard deviation: 0.702

# %%
sns.histplot(data=individual_means_of_100_samples_of_30,bins=30,stat='density',color='beige')
sns.kdeplot(data=individual_means_of_100_samples_of_30,color='red')
plt.xlabel('Height')
plt.ylabel('Probability Density')
plt.title('Means of 100 Samples of size = 30 Histogram')
plt.axvline(population_height_mean,label='Population mean',linewidth=2)
plt.axvline(mean_of_individual_means_of_30,label='Sample mean',linewidth=2,color='green')
plt.legend()
plt.show()

# %%
# 100 samples of size n = 50

random_5000 = np.array(data['Height'][np.random.randint(0,10000,5000)]).reshape(100,50)

individual_means_of_100_samples_of_50 = random_5000.mean(axis=1)

# %%
mean_of_individual_means_of_50 = round(individual_means_of_100_samples_of_50.mean(),3)
std_of_individual_means_of_50 = round(individual_means_of_100_samples_of_50.std(ddof=1),3)
theo_std_50 = round(population_height_std/(50)**(1/2),3)

print(f'Sample height mean: {mean_of_individual_means_of_50}','\n\n'
      f'Sample height standard deviation: {std_of_individual_means_of_50}','\n\n'
      f'Theoritical Sample height standard deviation: {theo_std_50}')
# Out:
# Sample height mean: 66.336
#
# Sample height standard deviation: 0.543
#
# Theoritical Sample height standard deviation: 0.544

# %%
sns.histplot(data=individual_means_of_100_samples_of_50,bins=30,stat='density',color='beige')
sns.kdeplot(data=individual_means_of_100_samples_of_50,color='red')
plt.xlabel('Height')
plt.ylabel('Probability Density')
plt.title('Means of 100 Samples of size = 50 Histogram')
plt.axvline(population_height_mean,label='Population mean',linewidth=2)
plt.axvline(mean_of_individual_means_of_50,label='Sample mean',linewidth=2,color='green')
plt.legend()
plt.show()

# %%
# 100 samples of size n = 100

random_10000 = np.array(data['Height'][np.random.randint(0,10000,10000)]).reshape(100,100)

individual_means_of_100_samples_of_100 = random_10000.mean(axis=1)

# %%
mean_of_individual_means_of_100 = round(individual_means_of_100_samples_of_100.mean(),3)
std_of_individual_means_of_100 = round(individual_means_of_100_samples_of_100.std(ddof=1),3)
theo_std_100 = round(population_height_std/(100)**(1/2),3)

print(f'Sample height mean: {mean_of_individual_means_of_100}','\n\n'
      f'Sample height standard deviation: {std_of_individual_means_of_100}','\n\n'
      f'Theoritical Sample height standard deviation: {theo_std_100}')
# Out:
# Sample height mean: 66.394
#
# Sample height standard deviation: 0.363
#
# Theoritical Sample height standard deviation: 0.385

# %%
sns.histplot(data=individual_means_of_100_samples_of_100,bins=30,stat='density',color='beige')
sns.kdeplot(data=individual_means_of_100_samples_of_100,color='red')
plt.xlabel('Height')
plt.ylabel('Probability Density')
plt.title('Means of 100 Samples of size = 100 Histogram')
plt.axvline(population_height_mean,label='Population mean',linewidth=2)
plt.axvline(mean_of_individual_means_of_100,label='Sample mean',linewidth=2,color='green')
plt.legend()
plt.show()

# %% [markdown]
# # **Sample Analysis For Sum:**

# %%
# 100 samples of size n = 5

random_500 = np.array(data['Height'][np.random.randint(0,10000,500)]).reshape(100,5)

individual_sums_of_100_samples_of_5 = random_500.sum(axis=1)

# %%
sum_of_individual_sums_of_5 = round(individual_sums_of_100_samples_of_5.sum(),3)
std_of_individual_sums_of_5 = round(individual_sums_of_100_samples_of_5.std(ddof=1),3)
theo_std_5_sum = round(population_height_std*(5)**(1/2),3)

print(f'Sample height sum: {sum_of_individual_sums_of_5}','\n\n'
      f'Sample height standard deviation: {std_of_individual_sums_of_5}','\n\n'
      f'Theoritical Sample height standard deviation: {theo_std_5_sum}')
# Out:
# Sample height sum: 33141.863
#
# Sample height standard deviation: 8.276
#
# Theoritical Sample height standard deviation: 8.602

# %%
sns.histplot(data=individual_sums_of_100_samples_of_5,bins=30,stat='density',color='beige')
sns.kdeplot(data=individual_sums_of_100_samples_of_5,color='red')
plt.xlabel('Height')
plt.ylabel('Probability Density')
plt.title('Sums of 100 Samples of size = 5 Histogram')
plt.show()

# %%
# 100 samples of size n = 10

random_1000 = np.array(data['Height'][np.random.randint(0,10000,1000)]).reshape(100,10)

individual_sums_of_100_samples_of_10 = random_1000.sum(axis=1)

# %%
sum_of_individual_sums_of_10 = round(individual_sums_of_100_samples_of_10.sum(),3)
std_of_individual_sums_of_10 = round(individual_sums_of_100_samples_of_10.std(ddof=1),3)
theo_std_10_sum = round(population_height_std*(10)**(1/2),3)

print(f'Sample height sum: {sum_of_individual_sums_of_10}','\n\n'
      f'Sample height standard deviation: {std_of_individual_sums_of_10}','\n\n'
      f'Theoritical Sample height standard deviation: {theo_std_10_sum}')
# Out:
# Sample height sum: 66464.712
#
# Sample height standard deviation: 12.777
#
# Theoritical Sample height standard deviation: 12.165

# %%
sns.histplot(data=individual_sums_of_100_samples_of_10,bins=30,stat='density',color='beige')
sns.kdeplot(data=individual_sums_of_100_samples_of_10,color='red')
plt.xlabel('Height')
plt.ylabel('Probability Density')
plt.title('Sums of 100 Samples of size = 10 Histogram')
plt.show()

# %%
# 100 samples of size n = 30

random_3000 = np.array(data['Height'][np.random.randint(0,10000,3000)]).reshape(100,30)

individual_sums_of_100_samples_of_30 = random_3000.sum(axis=1)

# %%
sum_of_individual_sums_of_30 = round(individual_sums_of_100_samples_of_30.sum(),3)
std_of_individual_sums_of_30 = round(individual_sums_of_100_samples_of_30.std(ddof=1),3)
theo_std_30_sum = round(population_height_std*(30)**(1/2),3)

print(f'Sample height sum: {sum_of_individual_sums_of_30}','\n\n'
      f'Sample height standard deviation: {std_of_individual_sums_of_30}','\n\n'
      f'Theoritical Sample height standard deviation: {theo_std_30_sum}')
# Out:
# Sample height sum: 199156.814
#
# Sample height standard deviation: 20.457
#
# Theoritical Sample height standard deviation: 21.071

# %%
sns.histplot(data=individual_sums_of_100_samples_of_30,bins=30,stat='density',color='beige')
sns.kdeplot(data=individual_sums_of_100_samples_of_30,color='red')
plt.xlabel('Height')
plt.ylabel('Probability Density')
plt.title('Sums of 100 Samples of size = 30 Histogram')
plt.show()

# %%
# 100 samples of size n = 50

random_5000 = np.array(data['Height'][np.random.randint(0,10000,5000)]).reshape(100,50)

individual_sums_of_100_samples_of_50 = random_5000.sum(axis=1)

# %%
sum_of_individual_sums_of_50 = round(individual_sums_of_100_samples_of_50.sum(),3)
std_of_individual_sums_of_50 = round(individual_sums_of_100_samples_of_50.std(ddof=1),3)
theo_std_50_sum = round(population_height_std*(50)**(1/2),3)

print(f'Sample height sum: {sum_of_individual_sums_of_50}','\n\n'
      f'Sample height standard deviation: {std_of_individual_sums_of_50}','\n\n'
      f'Theoritical Sample height standard deviation: {theo_std_50_sum}')
# Out:
# Sample height sum: 331504.44
#
# Sample height standard deviation: 23.25
#
# Theoritical Sample height standard deviation: 27.202

# %%
sns.histplot(data=individual_sums_of_100_samples_of_50,bins=30,stat='density',color='beige')
sns.kdeplot(data=individual_sums_of_100_samples_of_50,color='red')
plt.xlabel('Height')
plt.ylabel('Probability Density')
plt.title('Sums of 100 Samples of size = 50 Histogram')
plt.show()

# %%
# 100 samples of size n = 100

random_10000 = np.array(data['Height'][np.random.randint(0,10000,10000)]).reshape(100,100)

individual_sums_of_100_samples_of_100 = random_10000.sum(axis=1)

# %%
sum_of_individual_sums_of_100 = round(individual_sums_of_100_samples_of_100.sum(),3)
std_of_individual_sums_of_100 = round(individual_sums_of_100_samples_of_100.std(ddof=1),3)
theo_std_100_sum = round(population_height_std*(100)**(1/2),3)

print(f'Sample height sum: {sum_of_individual_sums_of_100}','\n\n'
      f'Sample height standard deviation: {std_of_individual_sums_of_100}','\n\n'
      f'Theoritical Sample height standard deviation: {theo_std_100_sum}')
# Out:
# Sample height sum: 663421.676
#
# Sample height standard deviation: 35.83
#
# Theoritical Sample height standard deviation: 38.47

# %%
sns.histplot(data=individual_sums_of_100_samples_of_100,bins=30,stat='density',color='beige')
sns.kdeplot(data=individual_sums_of_100_samples_of_100,color='red')
plt.xlabel('Height')
plt.ylabel('Probability Density')
plt.title('Sums of 100 Samples of size = 100 Histogram')
plt.show()
